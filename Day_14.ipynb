# %% [markdown]
# <a href="https://colab.research.google.com/github/kush2727/20-Day-Python-Programming-Prep-Series/blob/main/Day_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 66)Write a Python program to check whether two strings are Anagrams of each other without using built-in functions.

# %%
a="silent"
b="listen"
mark=0
a1=list(a)
b1=list(b)


if len(a1)!=len(b1):
    mark=1
else:
    n=len(a1)
    for i in range(0,n-1+1,1):
        for j in range(0,n-2+1,1):
            if a1[j]>a1[j+1]:
                c=a1[j]
                a1[j]=a1[j+1]
                a1[j+1]=c


    for i in range(0,n-1+1,1):
            for j in range(0,n-2+1,1):
                if b1[j]>b1[j+1]:
                    c=b1[j]
                    b1[j]=b1[j+1]
                    b1[j+1]=c


    for i in range(0,len(a1)-1+1,1):
        if a1[i]!=b1[i]:
            mark=1


if mark==1:
    print("Not Anagram")
else:
    print("Anagram")
# Out:
# Anagram

# %% [markdown]
# 67)Write a Python program to print the penultimate (second last) word of a given string.

# %%
a=input("Enter a String: ")
n=len(a)-1
count=0
while n>=0:
    if a[n]==" ":
        count+=1
    if count==2:
        n+=1
        break
    n-=1

if count<2:
    n=0

while n<len(a) and a[n]!=" ":
    print(a[n],end="")
    n+=1
# Out:
# Enter a String: Python is high level language
# level

# %% [markdown]
# 68)Write a Python program to count the number of uppercase letters, lowercase letters, digits, spaces, and special characters in a given string.

# %%
a=input("Enter String: ")
upper=0
lower=0
spaces=0
nums=0
special=0
for i in a:
    if i>="A" and i<="Z":
        upper+=1
    elif i>="a" and i<="z":
        lower+=1
    elif i==" ":
        spaces+=1
    elif i>="0" and i<="9":
        nums+=1
    else:
        special+=1

print(f"Lower case count: {lower}")
print(f"Upper case count: {upper}")
print(f"Spaces count: {spaces}")
print(f"digits count: {nums}")
print(f"Special case count: {special}")
# Out:
# Enter String: PYthOnProgramming@123#$
# Lower case count: 13
# Upper case count: 4
# Spaces count: 0
# digits count: 3
# Special case count: 3

# %% [markdown]
# 69)Write a program to reverse the order of words in a given string without using any built-in string functions like split().

# %%
a = "Python is Highlevel"
word = ""
words = []
for i in a+" ":
    if i != " ":
        word += i
    else:
        words.append(word)
        word = ""
rev=""
for i in words:
    rev=i+" "+rev

print(rev)
# Out:
# Highlevel is Python

# %% [markdown]
# 70)Write a program to remove all spaces from a string.

# %%
a = "Python is 3D language"
words=""
for i in a:
    if i!=" ":
        words+=i
print(words)
# Out:
# Pythonis3Dlanguage
